# %%
# %matplotlib qt5

# %%
import hyperspy.api as hs

# %%
s = hs.load("002_EELS-SI_1.7nm_2mmAp_MnFe_Stack_Average denoised.dm3")
s
# Out:
# <EELSSpectrum, title: 002_EELS-SI_1.7nm_2mmAp_MnFe_Stack_Average denoised, dimensions: (40, 236|1028)>

# %%
s.plot()

# %%
s = s.inav[1:-1, 1:-1]
s
# Out:
# <EELSSpectrum, title: 002_EELS-SI_1.7nm_2mmAp_MnFe_Stack_Average denoised, dimensions: (27, 223|1028)>

# %%
s.plot()

# %%
s.set_microscope_parameters(beam_energy=100, collection_angle=50, convergence_angle=30)

# %%
s.decomposition(normalize_poissonian_noise=True)
# Out:
# Decomposition info:
#   normalize_poissonian_noise=True
#   algorithm=SVD
#   output_dimension=None
#   centre=None

# %%
s.plot_explained_variance_ratio()
# Out:
# <Axes: title={'center': '002_EELS-SI_1.7nm_2mmAp_MnFe_Stack_Average denoised\nPCA Scree Plot'}, xlabel='Principal component index', ylabel='Proportion of variance'>

# %%
s_denoised = s.get_decomposition_model(components=3)

# %%
s_denoised.plot()

# %%
s.blind_source_separation(3)
# Out:
# [########################################] | 100% Completed | 115.79 ms
# WARNING:hyperspy.learn.mva:HyperSpy already performs its own data whitening (whiten_method='PCA'), so it is ignored for algorithm='sklearn_fastica'.
# Blind source separation info:
#   number_of_components=3
#   algorithm=sklearn_fastica
#   diff_order=1
#   reverse_component_criterion=factors
#   whiten_method=PCA
# scikit-learn estimator:
# FastICA(tol=1e-10, whiten=False)
# C:\Users\gerit\mambaforge\envs\hyperspy_env\lib\site-packages\sklearn\decomposition\_fastica.py:123: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(

# %%
s.plot_bss_factors()

# %%
s.plot_bss_loadings()
